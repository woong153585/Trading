# %%
import os
import numpy as np
import pandas as pd
from dotenv import load_dotenv
from binance import Client
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential, save_model
from tensorflow.keras.layers import LSTM, Dense

# Binance 클라이언트 초기화
client = Client(api_key, api_secret)

# 환경 변수 로드
load_dotenv()
api_key = os.getenv('BINANCE_API_KEY')
api_secret = os.getenv('BINANCE_SECRET_KEY')

# Binance 클라이언트 초기화 (이 부분이 누락되었습니다)
client = Client(api_key, api_secret)

# 모델 파라미터 설정
SYMBOL = 'XRPUSDT'
MODEL_PATH = 'xrp_lstm.h5'
SEQ_LENGTH = 60

# LSTM 모델 초기화
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(SEQ_LENGTH, 1)))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# 과거 데이터 1000개 이상 수집
klines = client.get_historical_klines(SYMBOL, '1m', '1000 minutes ago UTC')
prices = [float(k[4]) for k in klines]

# 데이터 전처리
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_prices = scaler.fit_transform(np.array(prices).reshape(-1,1))

X_train, y_train = [], []
for i in range(SEQ_LENGTH, len(scaled_prices)):
    X_train.append(scaled_prices[i-SEQ_LENGTH:i, 0])
    y_train.append(scaled_prices[i, 0])
    
X_train = np.array(X_train).reshape(-1, SEQ_LENGTH, 1)
y_train = np.array(y_train)

# 모델 학습
model.fit(X_train, y_train, epochs=50, batch_size=32)
save_model(model, MODEL_PATH)

print(f"모델이 성공적으로 학습되었으며 {MODEL_PATH}에 저장되었습니다.")
print(f"학습에 사용된 데이터 포인트: {len(prices)}개")
print(f"학습 샘플 수: {len(X_train)}개")
# Out:
# d:\Programs\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - loss: 0.1050
# Epoch 2/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0053
# Epoch 3/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0039
# Epoch 4/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0035
# Epoch 5/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0030
# Epoch 6/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0024
# Epoch 7/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0023
# Epoch 8/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0021
# Epoch 9/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0020
# Epoch 10/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0020
# Epoch 11/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0019
# Epoch 12/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0020
# Epoch 13/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0018
# Epoch 14/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0018
# Epoch 15/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0016
# Epoch 16/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0016
# Epoch 17/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0016
# Epoch 18/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0015
# Epoch 19/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0014
# Epoch 20/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0014
# Epoch 21/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0017
# Epoch 22/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0013
# Epoch 23/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0015
# Epoch 24/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0013
# Epoch 25/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0014
# Epoch 26/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0013
# Epoch 27/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0012
# Epoch 28/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0012
# Epoch 29/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0011
# Epoch 30/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0012
# Epoch 31/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0011
# Epoch 32/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.5513e-04
# Epoch 33/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0011
# Epoch 34/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0012
# Epoch 35/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0010
# Epoch 36/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0013
# Epoch 37/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.7499e-04
# Epoch 38/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.4005e-04
# Epoch 39/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.4331e-04
# Epoch 40/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.0915e-04
# Epoch 41/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.3777e-04
# Epoch 42/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.7887e-04
# Epoch 43/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0010
# Epoch 44/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.1598e-04
# Epoch 45/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.4661e-04
# Epoch 46/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.0006e-04
# Epoch 47/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.1531e-04
# Epoch 48/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.9715e-04
# Epoch 49/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.9250e-04
# Epoch 50/50
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.1948e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 모델이 성공적으로 학습되었으며 xrp_lstm.h5에 저장되었습니다.
# 학습에 사용된 데이터 포인트: 1000개
# 학습 샘플 수: 940개
